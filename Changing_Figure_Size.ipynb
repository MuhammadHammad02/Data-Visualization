# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadHammad02/Data-Visualization/blob/main/Changing_Figure_Size.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
years = range(2000,2010)
apples=[0.895,0.91,0.919,0.926,0.929,0.931,0.934,0.936,0.937,0.938]
oranges=[0.962,0.942,0.935,0.929,0.920,0.915,0.910,0.908,0.900,0.895]

# %%
plt.figure(figsize=(12,6))
plt.plot(years, oranges, 'or')
plt.title('Yield of Oranges (tons per hactare)')
# Out:
# Text(0.5, 1.0, 'Yield of Oranges (tons per hactare)')

# %%
plt.figure(figsize=(2,2))
plt.plot(years, oranges, 'or')
plt.title('Yield of Oranges (tons per hactare)')
# Out:
# Text(0.5, 1.0, 'Yield of Oranges (tons per hactare)')

# %%
plt.figure(figsize=(6,12))
plt.plot(years, oranges, 'or')
plt.title('Yield of Oranges (tons per hactare)')
# Out:
# Text(0.5, 1.0, 'Yield of Oranges (tons per hactare)')

# %%
plt.figure(figsize=(15,5))
plt.plot(years, oranges, 'or')
plt.title('Yield of Oranges (tons per hactare)')
# Out:
# Text(0.5, 1.0, 'Yield of Oranges (tons per hactare)')

# %%
plt.figure(figsize=(12,6))
plt.plot(years, oranges, 'or')
plt.title('Yield of Oranges (tons per hactare)')
# Out:
# Text(0.5, 1.0, 'Yield of Oranges (tons per hactare)')
